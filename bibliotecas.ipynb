# %%
#Importação de bibliotecas
import numpy as np #np será o apelido

# %%
temperaturas = np.array([30,40,50,60,70,90,100])
print(temperaturas)
print(temperaturas + 10)
print(type(temperaturas))
# Out:
# [ 30  40  50  60  70  90 100]
# [ 40  50  60  70  80 100 110]
# <class 'numpy.ndarray'>

# %%
#Média aritmética
media = np.mean(temperaturas)
print(f"{media:.1f}")
# Out:
# 62.9

# %%
#Retorna o maior valor da lista
maior_valor = np.max(temperaturas)
print(maior_valor)
# Out:
# 100

# %%
#Exibir o menor valor
menor_valor = np.min(temperaturas)
print(menor_valor)
# Out:
# 30

# %%
#Salários x 1000
salarios = np.array([2,3,4,5,1,500])
media_salarios = np.mean(salarios)
print(f"{media_salarios:.2f}")
# Out:
# 85.83

# %%
mediana = np.median(salarios)
print(mediana)
# Out:
# 3.5

# %% [markdown]
# Desafio final:
# - Criar um array de habitantes de 5 cidades do estado de SP.
# - Maior população
# - Menor população
# - Média de população
# - Mediana

# %%
populacoes = np.array([1000000,200000])
print(f"A cidade de Campinas possui {populacoes[0]} habitantes")
# Out:
# A cidade de Campinas possui 1000000 habitantes

# %%
numeros = np.array([2,3,4,5,6,7,8])
print(np.median(numeros))
# Out:
# 5.0

# %%
conjunto = np.array([2,3,4,5,6,7])
print(np.median(conjunto))
# Out:
# 4.5
